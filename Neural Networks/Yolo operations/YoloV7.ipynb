# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# 'git' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pwd
# Out:
# 'c:\\Users\\varun\\OneDrive\\Desktop\\Fall Sem\\Smart Internz AI&ML\\9_Yolo operations'

# %%
# %cd yolov7/
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov7/'
# c:\Users\varun\OneDrive\Desktop\Fall Sem\Smart Internz AI&ML\9_Yolo operations

# %%
pwd
# Out:
# 'c:\\Users\\varun\\OneDrive\\Desktop\\Fall Sem\\Smart Internz AI&ML\\9_Yolo operations'

# %%
# !pip install -U -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python detect.py --weights yolov7.pt --conf 0.50 --img-size 640 --source inference/images/horses.jpg
# Out:
# Namespace(weights=['yolov7.pt'], source='inference/images/horses.jpg', img_size=640, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-126-g84932d7 torch 2.1.0+cu121 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients, 104.5 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
#printing the predicted image
from IPython.display import  display, Image

# %%
Image(filename='/content/yolov7/runs/detect/exp/horses.jpg')

# %%
Image(filename='/content/yolov7/runs/detect/exp2/horses.jpg')

# %%
Image(filename='/content/yolov7/runs/detect/exp3/horses.jpg')
