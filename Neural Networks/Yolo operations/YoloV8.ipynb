# %%
# !nvidia-smi
# Out:
# Thu Oct  5 14:07:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.3/617.3 kB 6.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import display,Image

# %%
#Detection-prediction
# !yolo task=detect mode= predict model =yolov8n.pt source="https://production-media.paperswithcode.com/thumbnails/task/task-0000000745-802706d9.jpg"
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 331MB/s]
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 22.4k/22.4k [00:00<00:00, 57.3MB/s]
# image 1/1 /content/task-0000000745-802706d9.jpg: 384x640 8 cars, 1 bus, 99.1ms
# Speed: 13.0ms preprocess, 99.1ms inference, 30.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename="/content/task-0000000745-802706d9.jpg")

# %%
Image("/content/runs/detect/predict/task-0000000745-802706d9.jpg")

# %%
#Image segmentation color bounded box
# !yolo task=segment mode=predict model=yolov8n-seg.pt conf=0.25 source='https://img.freepik.com/premium-vector/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg'  #-seg.pt takes the segmentation model's weight
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients, 12.6 GFLOPs
#
# ...
# 100% 31.2k/31.2k [00:00<00:00, 163kB/s]
# image 1/1 /content/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg: 512x640 3 refrigerators, 138.6ms
# Speed: 3.9ms preprocess, 138.6ms inference, 2.7ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs/segment/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg')

# %%
Image(filename='/content/runs/segment/predict/vector-set-realistic-colorful-empty-shopping-bags-promotion-isolated-white-background_572288-732.jpg')

# %%
# classify

# !yolo task=classify mode=predict model=yolov8n-cls.pt conf=0.25 source='/content/task-0000000745-802706d9.jpg'
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-cls summary (fused): 73 layers, 2715880 parameters, 0 gradients, 4.3 GFLOPs
#
# image 1/1 /content/task-0000000745-802706d9.jpg: 224x224 forklift 0.20, dock 0.08, container_ship 0.07, crane_(machine) 0.06, tow_truck 0.04, 2.7ms
# Speed: 1.5ms preprocess, 2.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='/content/runs/classify/predict2/task-0000000745-802706d9.jpg')

# %% [markdown]
# For training custom dataset

# %%
##    !yolo task=detect mode=train model=yolov8l.pt data =/content/plastics-3/data.yaml epochs=50 imgsz=640
